# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import (
    layers,
    models,
    callbacks,
    utils,
    metrics,
    losses,
    optimizers,
)

from scipy.stats import norm
import pandas as pd

from utils import sample_batch, display

from vae_utils import get_vector_from_label, add_vector_to_images, morph_faces
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 20
#       9 from tensorflow.keras import (
#      10     layers,
#      11     models,
#    (...)
#      16     optimizers,
#      17 )
#      19 from scipy.stats import norm
# ---> 20 import pandas as pd
#      22 from utils import sample_batch, display
#      24 from vae_utils import get_vector_from_label, add_vector_to_images, morph_faces
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# zsh:1: command not found: pip

# %%
# !pip3 install pandas
# Out:
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try brew install
#     xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a Python library that isn't in Homebrew,
#     use a virtual environment:
#
#     python3 -m venv path/to/venv
#     source path/to/venv/bin/activate
#     python3 -m pip install xyz
#
#     If you wish to install a Python application that isn't in Homebrew,
#     it may be easiest to use 'pipx install xyz', which will manage a
#     virtual environment for you. You can install pipx with
#
#     brew install pipx
#
#     You may restore the old behavior of pip by passing
#     the '--break-system-packages' flag to pip, or by adding
#     'break-system-packages = true' to your pip.conf file. The latter
#     will permanently disable this error.
#
#     If you disable this error, we STRONGLY recommend that you additionally
#     pass the '--user' flag to pip, or set 'user = true' in your pip.conf
#     file. Failure to do this can result in a broken Homebrew installation.
#
#     Read more about this behavior here: <https://peps.python.org/pep-0668/>
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.

# %%
IMAGE_SIZE = 64
CHANNELS = 3
BATCH_SIZE = 51
NUM_FEATURES = 20
Z_DIM = 10
LEARNING_RATE = 0.0005
EPOCHS = 2000
BETA = 2000
LOAD_MODEL = False

# %%
# Load the data
train_data = utils.image_dataset_from_directory(
    "/Users/ajayramaraju/Desktop/RA/My VAE/Microstructure",
    labels=None,
    color_mode="rgb",
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=42,
    interpolation="bilinear",
)
# Out:
# Found 40 files belonging to 1 classes.

# %%
# Preprocess the data
def preprocess(img):
    img = tf.cast(img, "float32") / 255.0
    return img


train = train_data.map(lambda x: preprocess(x))

# %%
train_sample = sample_batch(train)

# %%
# Show some faces from the training set
display(train_sample, cmap=None)

# %% [markdown]
# 2. Build the variational autoencoder

# %%
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = K.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
# Encoder
encoder_input = layers.Input(
    shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS), name="encoder_input"
)
x = layers.Conv2D(NUM_FEATURES, kernel_size=3, strides=2, padding="same")(
    encoder_input
)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(NUM_FEATURES, kernel_size=3, strides=2, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(NUM_FEATURES, kernel_size=3, strides=2, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(NUM_FEATURES, kernel_size=3, strides=2, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(NUM_FEATURES, kernel_size=3, strides=2, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
shape_before_flattening = K.int_shape(x)[1:]  # the decoder will need this!

x = layers.Flatten()(x)
z_mean = layers.Dense(Z_DIM, name="z_mean")(x)
z_log_var = layers.Dense(Z_DIM, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])

encoder = models.Model(encoder_input, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  encoder_input (InputLayer)  [(None, 64, 64, 3)]          0         []
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 20)           560       ['encoder_input[0][0]']
#
#  batch_normalization_11 (Ba  (None, 32, 32, 20)           80        ['conv2d_5[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 32, 32, 20)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 20)           3620      ['leaky_re_lu_11[0][0]']
#
#  batch_normalization_12 (Ba  (None, 16, 16, 20)           80        ['conv2d_6[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 16, 16, 20)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 20)             3620      ['leaky_re_lu_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 8, 8, 20)             80        ['conv2d_7[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 8, 8, 20)             0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 20)             3620      ['leaky_re_lu_13[0][0]']
#
#  batch_normalization_14 (Ba  (None, 4, 4, 20)             80        ['conv2d_8[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 4, 4, 20)             0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_9 (Conv2D)           (None, 2, 2, 20)             3620      ['leaky_re_lu_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 2, 2, 20)             80        ['conv2d_9[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 2, 2, 20)             0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  flatten_1 (Flatten)         (None, 80)                   0         ['leaky_re_lu_15[0][0]']
#
#  z_mean (Dense)              (None, 10)                   810       ['flatten_1[0][0]']
#
#  z_log_var (Dense)           (None, 10)                   810       ['flatten_1[0][0]']
#
#  sampling_1 (Sampling)       (None, 10)                   0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 17060 (66.64 KB)
# Trainable params: 16860 (65.86 KB)
# Non-trainable params: 200 (800.00 Byte)
# __________________________________________________________________________________________________

# %%
# Decoder
decoder_input = layers.Input(shape=(Z_DIM,), name="decoder_input")
x = layers.Dense(np.prod(shape_before_flattening))(decoder_input)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Reshape(shape_before_flattening)(x)
x = layers.Conv2DTranspose(
    NUM_FEATURES, kernel_size=3, strides=2, padding="same"
)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2DTranspose(
    NUM_FEATURES, kernel_size=3, strides=2, padding="same"
)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2DTranspose(
    NUM_FEATURES, kernel_size=3, strides=2, padding="same"
)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2DTranspose(
    NUM_FEATURES, kernel_size=3, strides=2, padding="same"
)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2DTranspose(
    NUM_FEATURES, kernel_size=3, strides=2, padding="same"
)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
decoder_output = layers.Conv2DTranspose(
    CHANNELS, kernel_size=3, strides=1, activation="sigmoid", padding="same"
)(x)
decoder = models.Model(decoder_input, decoder_output)
decoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  decoder_input (InputLayer)  [(None, 10)]              0
#
#  dense_1 (Dense)             (None, 80)                880
#
#  batch_normalization_16 (Ba  (None, 80)                320
#  tchNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 80)                0
#
#  reshape_1 (Reshape)         (None, 2, 2, 20)          0
#
#  conv2d_transpose_6 (Conv2D  (None, 4, 4, 20)          3620
#  Transpose)
#
#  batch_normalization_17 (Ba  (None, 4, 4, 20)          80
#  tchNormalization)
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 4, 4, 20)          0
#
#  conv2d_transpose_7 (Conv2D  (None, 8, 8, 20)          3620
#  Transpose)
#
#  batch_normalization_18 (Ba  (None, 8, 8, 20)          80
#  tchNormalization)
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 8, 8, 20)          0
#
#  conv2d_transpose_8 (Conv2D  (None, 16, 16, 20)        3620
#  Transpose)
#
#  batch_normalization_19 (Ba  (None, 16, 16, 20)        80
#  tchNormalization)
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 16, 16, 20)        0
#
#  conv2d_transpose_9 (Conv2D  (None, 32, 32, 20)        3620
#  Transpose)
#
#  batch_normalization_20 (Ba  (None, 32, 32, 20)        80
#  tchNormalization)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 32, 32, 20)        0
#
#  conv2d_transpose_10 (Conv2  (None, 64, 64, 20)        3620
#  DTranspose)
#
#  batch_normalization_21 (Ba  (None, 64, 64, 20)        80
#  tchNormalization)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 64, 64, 20)        0
#
#  conv2d_transpose_11 (Conv2  (None, 64, 64, 3)         543
#  DTranspose)
#
# =================================================================
# Total params: 20243 (79.07 KB)
# Trainable params: 19883 (77.67 KB)
# Non-trainable params: 360 (1.41 KB)
# _________________________________________________________________

# %%
class VAE(models.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def call(self, inputs):
        """Call the model on a particular input."""
        z_mean, z_log_var, z = encoder(inputs)
        reconstruction = decoder(z)
        return z_mean, z_log_var, reconstruction

    def train_step(self, data):
        """Step run during training."""
        with tf.GradientTape() as tape:
            z_mean, z_log_var, reconstruction = self(data, training=True)
            reconstruction_loss = tf.reduce_mean(
                BETA * losses.mean_squared_error(data, reconstruction)
            )
            kl_loss = tf.reduce_mean(
                tf.reduce_sum(
                    -0.5
                    * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)),
                    axis=1,
                )
            )
            total_loss = reconstruction_loss + kl_loss

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)

        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data):
        """Step run during validation."""
        if isinstance(data, tuple):
            data = data[0]

        z_mean, z_log_var, reconstruction = self(data)
        reconstruction_loss = tf.reduce_mean(
            BETA * losses.mean_squared_error(data, reconstruction)
        )
        kl_loss = tf.reduce_mean(
            tf.reduce_sum(
                -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)),
                axis=1,
            )
        )
        total_loss = reconstruction_loss + kl_loss
        
        return {
            "loss": total_loss,
            "reconstruction_loss": reconstruction_loss,
            "kl_loss": kl_loss,
        }

# %%
# Create a variational autoencoder
vae = VAE(encoder, decoder)

# %% [markdown]
# 3. Train the variational autoencoder

# %%
# Compile the variational autoencoder
optimizer = optimizers.Adam(learning_rate=LEARNING_RATE)
vae.compile(optimizer=optimizer)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %%
# Create a model save checkpoint
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath="./checkpoint",
    save_weights_only=False,
    save_freq="epoch",
    monitor="loss",
    mode="min",
    save_best_only=True,
    verbose=0,
)

tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")


class ImageGenerator(callbacks.Callback):
    def __init__(self, num_img, latent_dim):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = tf.random.normal(
            shape=(self.num_img, self.latent_dim)
        )
        generated_images = self.model.decoder(random_latent_vectors)
        generated_images *= 255
        generated_images.numpy()
        for i in range(self.num_img):
            img = utils.array_to_img(generated_images[i])
            img.save("./output/generated_img_%03d_%d.png" % (epoch, i))

# %%
# Load old weights if required
if LOAD_MODEL:
    vae.load_weights("./models/vae")
    tmp = vae.predict(train.take(1))

# %%
vae.fit(
    train,
    epochs=EPOCHS,
    callbacks=[
        model_checkpoint_callback,
        tensorboard_callback,
        ImageGenerator(num_img=10, latent_dim=Z_DIM),
    ],
)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - ETA: 0s - loss: 473.0943 - reconstruction_loss: 465.0453 - kl_loss: 8.0490WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 1/1 [==============================] - 3s 3s/step - loss: 473.0943 - reconstruction_loss: 465.0453 - kl_loss: 8.0490
# Epoch 2/2000
# 1/1 [==============================] - ETA: 0s - loss: 461.0219 - reconstruction_loss: 454.5663 - kl_loss: 6.4556WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 1/1 [==============================] - 2s 2s/step - loss: 461.0219 - reconstruction_loss: 454.5663 - kl_loss: 6.4556
# Epoch 3/2000
# 1/1 [==============================] - ETA: 0s - loss: 450.2032 - reconstruction_loss: 444.6949 - kl_loss: 5.5083WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 1/1 [==============================] - 2s 2s/step - loss: 450.2032 - reconstruction_loss: 444.6949 - kl_loss: 5.5083
# Epoch 4/2000
# 1/1 [==============================] - ETA: 0s - loss: 440.0107 - reconstruction_loss: 435.0754 - kl_loss: 4.9353WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 1/1 [==============================] - 1s 1s/step - loss: 440.0107 - reconstruction_loss: 435.0754 - kl_loss: 4.9353
# Epoch 5/2000
# 1/1 [==============================] - ETA: 0s - loss: 432.6858 - reconstruction_loss: 428.0652 - kl_loss: 4.6206WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 1/1 [==============================] - 2s 2s/step - loss: 432.6858 - reconstruction_loss: 428.0652 - kl_loss: 4.6206
# Epoch 6/2000
# 1/1 [==============================] - ETA: 0s - loss: 422.7952 - reconstruction_loss: 418.4284 - kl_loss: 4.3668WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 1/1 [==============================] - 2s 2s/step - loss: 422.7952 - reconstruction_loss: 418.4284 - kl_loss: 4.3668
# Epoch 7/2000
# 1/1 [==============================] - ETA: 0s - loss: 415.4811 - reconstruction_loss: 411.3591 - kl_loss: 4.1219WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 1/1 [==============================] - 2s 2s/step - loss: 415.4811 - reconstruction_loss: 411.3591 - kl_loss: 4.1219
# Epoch 8/2000
# 1/1 [==============================] - ETA: 0s - loss: 407.4760 - reconstruction_loss: 403.6231 - kl_loss: 3.8529WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 1/1 [==============================] - 1s 1s/step - loss: 407.4760 - reconstruction_loss: 403.6231 - kl_loss: 3.8529
# Epoch 9/2000
# 1/1 [==============================] - ETA: 0s - loss: 397.0691 - reconstruction_loss: 393.5372 - kl_loss: 3.5318WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 1/1 [==============================] - 2s 2s/step - loss: 397.0691 - reconstruction_loss: 393.5372 - kl_loss: 3.5318
# Epoch 10/2000
# 1/1 [==============================] - ETA: 0s - loss: 390.3919 - reconstruction_loss: 387.1760 - kl_loss: 3.2159WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 1/1 [==============================] - 2s 2s/step - loss: 390.3919 - reconstruction_loss: 387.1760 - kl_loss: 3.2159
# Epoch 11/2000
# 1/1 [==============================] - ETA: 0s - loss: 382.9414 - reconstruction_loss: 380.0230 - kl_loss: 2.9184WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 1/1 [==============================] - 2s 2s/step - loss: 382.9414 - reconstruction_loss: 380.0230 - kl_loss: 2.9184
# Epoch 12/2000
# 1/1 [==============================] - ETA: 0s - loss: 375.4998 - reconstruction_loss: 372.8297 - kl_loss: 2.6700WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# INFO:tensorflow:Assets written to: ./checkpoint/assets
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 1/1 [==============================] - 1s 1s/step - loss:
2000
# 1/1 [==============================] - 0s 110ms/step - loss: 58.6315 - reconstruction_loss: 57.5268 - kl_loss: 1.1047
# Epoch 1990/2000
# 1/1 [==============================] - 0s 113ms/step - loss: 58.7130 - reconstruction_loss: 57.6229 - kl_loss: 1.0902
# Epoch 1991/2000
# 1/1 [==============================] - 0s 109ms/step - loss: 58.7340 - reconstruction_loss: 57.6571 - kl_loss: 1.0769
# Epoch 1992/2000
# 1/1 [==============================] - 0s 111ms/step - loss: 58.6290 - reconstruction_loss: 57.5605 - kl_loss: 1.0685
# Epoch 1993/2000
# 1/1 [==============================] - 0s 139ms/step - loss: 58.6009 - reconstruction_loss: 57.5430 - kl_loss: 1.0579
# Epoch 1994/2000
# 1/1 [==============================] - 0s 114ms/step - loss: 58.7575 - reconstruction_loss: 57.7117 - kl_loss: 1.0458
# Epoch 1995/2000
# 1/1 [==============================] - 0s 111ms/step - loss: 58.8444 - reconstruction_loss: 57.8023 - kl_loss: 1.0420
# Epoch 1996/2000
# 1/1 [==============================] - 0s 114ms/step - loss: 58.9814 - reconstruction_loss: 57.9329 - kl_loss: 1.0485
# Epoch 1997/2000
# 1/1 [==============================] - 0s 110ms/step - loss: 58.7773 - reconstruction_loss: 57.7088 - kl_loss: 1.0685
# Epoch 1998/2000
# 1/1 [==============================] - 0s 113ms/step - loss: 58.6571 - reconstruction_loss: 57.5657 - kl_loss: 1.0914
# Epoch 1999/2000
# 1/1 [==============================] - 0s 118ms/step - loss: 58.8620 - reconstruction_loss: 57.7546 - kl_loss: 1.1074
# Epoch 2000/2000
# 1/1 [==============================] - 0s 193ms/step - loss: 58.7123 - reconstruction_loss: 57.5912 - kl_loss: 1.1211

# %%
# Save the final models
vae.save("./models/vae")
encoder.save("./models/encoder")
decoder.save("./models/decoder")# Save the final models
vae.save("./models/vae")
encoder.save("./models/encoder")
decoder.save("./models/decoder")
# Out:
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# INFO:tensorflow:Assets written to: ./models/vae/assets
# INFO:tensorflow:Assets written to: ./models/vae/assets
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: ./models/encoder/assets
# INFO:tensorflow:Assets written to: ./models/encoder/assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: ./models/decoder/assets
# INFO:tensorflow:Assets written to: ./models/decoder/assets
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# INFO:tensorflow:Assets written to: ./models/vae/assets
# INFO:tensorflow:Assets written to: ./models/vae/assets
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: ./models/encoder/assets
# INFO:tensorflow:Assets written to: ./models/encoder/assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: ./models/decoder/assets
# INFO:tensorflow:Assets written to: ./models/decoder/assets

# %% [markdown]
# 3. Reconstruct using the variational autoencoder

# %%
# Select a subset of the test set
batches_to_predict = 1
example_images = np.array(
    list(train.take(batches_to_predict).get_single_element())
)

# %%
# Create autoencoder predictions and display
z_mean, z_log_var, reconstructions = vae.predict(example_images)
print("Example real Structures")
display(example_images)
print("Reconstructions")
display(reconstructions)
# Out:
# 2/2 [==============================] - 0s 10ms/step
# Example real Structures
# Reconstructions

# %% [markdown]
# 4. Latent space distribution

# %%
_, _, z = vae.encoder.predict(example_images)

x = np.linspace(-3, 3, 100)

fig = plt.figure(figsize=(20, 5))
fig.subplots_adjust(hspace=0.6, wspace=0.4)

for i in range(50):
    ax = fig.add_subplot(5, 10, i + 1)
    ax.hist(z[:, i], density=True, bins=20)
    ax.axis("off")
    ax.text(
        0.5, -0.35, str(i), fontsize=10, ha="center", transform=ax.transAxes
    )
    ax.plot(x, norm.pdf(x))

plt.show()
# Out:
# 2/2 [==============================] - 0s 2ms/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[44], line 10
#       8 for i in range(50):
#       9     ax = fig.add_subplot(5, 10, i + 1)
# ---> 10     ax.hist(z[:, i], density=True, bins=20)
#      11     ax.axis("off")
#      12     ax.text(
#      13         0.5, -0.35, str(i), fontsize=10, ha="center", transform=ax.transAxes
#      14     )
#
# IndexError: index 10 is out of bounds for axis 1 with size 10

# %% [markdown]
# 5. Generate new faces

# %%
# Sample some points in the latent space, from the standard normal distribution
grid_width, grid_height = (10, 3)
z_sample = np.random.normal(size=(grid_width * grid_height, Z_DIM))

# %%
# Decode the sampled points
reconstructions = decoder.predict(z_sample)
# Out:
# 1/1 [==============================] - 0s 163ms/step

# %%
# Draw a plot of decoded images
fig = plt.figure(figsize=(18, 5))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

# Output the grid of faces
for i in range(grid_width * grid_height):
    ax = fig.add_subplot(grid_height, grid_width, i + 1)
    ax.axis("off")
    ax.imshow(reconstructions[i, :, :])

# %% [markdown]
# 6. Manipulate the images

# %%
import pandas as pd
# Load the label dataset
attributes = pd.read_csv("/Users/ajayramaraju/Desktop/Microstructure Dataset (1)...csv")
print(attributes.columns)
attributes.head()
# Out:
# Index(['Image', 'Porosity10', 'Porosity50', 'Unnamed: 3'], dtype='object')
#                        Image  Porosity10  Porosity50  Unnamed: 3
# 0  Image1_Poro0.10_SArea0.10           1          -1         NaN
# 1  Image1_Poro0.50_SArea0.66          -1           1         NaN
# 2  Image2_Poro0.10_SArea0.10           1          -1         NaN
# 3  Image2_Poro0.50_SArea0.66          -1           1         NaN
# 4  Image3_Poro0.10_SArea0.10           1          -1         NaN

# %%
LABEL = "Porosity50"  # <- Set this label
labelled_test = utils.image_dataset_from_directory(
    "/Users/ajayramaraju/Desktop/RA/My VAE/Microstructure",
    labels=attributes[LABEL].tolist(),
    color_mode="rgb",
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=42,
    validation_split=0.2,
    subset="validation",
    interpolation="bilinear",
)

labelled = labelled_test.map(lambda x, y: (preprocess(x), y))
# Out:
# Found 40 files belonging to 2 classes.
# Using 8 files for validation.

# %%
# Find the attribute vector
attribute_vec = get_vector_from_label(labelled, vae, Z_DIM, LABEL)
# Out:
# label: Porosity50
# images : POS move : NEG move :distance : 𝛥 distance
# 1    : 3.632    : 1.609    : 4.07    : 4.07
# 2    : 2.152    : 0.659    : 2.877    : -1.193
# 3    : 1.539    : 0.443    : 2.735    : -0.142
# 4    : 0.996    : 0.287    : 2.541    : -0.194
# 5    : 0.492    : 0.281    : 2.618    : 0.076
# 6    : 0.442    : 0.198    : 2.588    : -0.029
# 7    : 0.438    : 0.124    : 2.483    : -0.105
# 8    : 0.438    : 0.116    : 2.372    : -0.111
# 9    : 0.258    : 0.095    : 2.35    : -0.022
# 10    : 0.345    : 0.083    : 2.213    : -0.137
# 11    : 0.25    : 0.165    : 2.128    : -0.084
# 12    : 0.236    : 0.13    : 2.1    : -0.028
# 13    : 0.259    : 0.086    : 2.122    : 0.023
# 14    : 0.313    : 0.106    : 2.073    : -0.049
# 15    : 0.224    : 0.085    : 2.084    : 0.011
# 16    : 0.169    : 0.101    : 1.989    : -0.096
# 17    : 0.197    : 0.092    : 2.006    : 0.017
# 18    : 0.127    : 0.053    : 2.001    : -0.006
# 19    : 0.206    : 0.076    : 2.032    : 0.031
# 20    : 0.131    : 0.047    : 2.027    : -0.004
# 21    : 0.159    : 0.068    : 2.051    : 0.023
# 22    : 0.128    : 0.044    : 2.017    : -0.034
# 23    : 0.125    : 0.034    : 2.015    : -0.001
# 24    : 0.115    : 0.044    : 1.994    : -0.021
# 25    : 0.096    : 0.029    : 1.963    : -0.031
# 26    : 0.093    : 0.039    : 1.964    : 0.001
# 27    : 0.103    : 0.03    : 1.959    : -0.005
# 28    : 0.116    : 0.055    : 1.963    : 0.004
# 29    : 0.094    : 0.044    : 1.973    : 0.01
# 30    : 0.083    : 0.035    : 1.987    : 0.013
# 31    : 0.133    : 0.023    : 1.995    : 0.008
# 32    : 0.117    : 0.036    : 1.979    : -0.016
# 33    : 0.061    : 0.04    : 1.983    : 0.004
# 34    : 0.057    : 0.032    : 1.962    : -0.021
# 35    : 0.083    : 0.029    : 1.973    : 0.011
# 36    : 0.081    : 0.035    : 1.964    : -0.009
# 37    : 0.097    : 0.044    : 1.976    : 0.011
# 38    : 0.077    : 0.042    : 1.962    : -0.014
# 39    : 0.086    : 0.028    : 1.953    : -0.009
# 40    : 0.044    : 0.032    : 1.942    : -0.012
# Found the Porosity50 vector

# %%
# Add vector to images
add_vector_to_images(labelled, vae, attribute_vec)

# %%
morph_faces(labelled, vae)
